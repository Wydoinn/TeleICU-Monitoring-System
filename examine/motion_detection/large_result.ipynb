# %% [markdown]
# # Examine Training Results of Motion Detection large Model

# %%
from IPython.display import Image

# %% [markdown]
# ## Training Results

# %%
Image(filename="/Users/wydoinn/Documents/TeleICU Monitoring System/runs/motion_detection/large_runs/detect/train/results.png", width=1000)

# %% [markdown]
# ## Confusion Matrix

# %%
Image(filename="/Users/wydoinn/Documents/TeleICU Monitoring System/runs/motion_detection/large_runs/detect/train/confusion_matrix.png", width=800)

# %% [markdown]
# ## Confusion Matrix (Normalized)

# %%
Image(filename="/Users/wydoinn/Documents/TeleICU Monitoring System/runs/motion_detection/large_runs/detect/train/confusion_matrix_normalized.png", width=800)

# %% [markdown]
# ## F1 Curve

# %%
Image(filename="/Users/wydoinn/Documents/TeleICU Monitoring System/runs/motion_detection/large_runs/detect/train/F1_curve.png", width=600)

# %% [markdown]
# ## Precision-Confidence Curve

# %%
Image(filename="/Users/wydoinn/Documents/TeleICU Monitoring System/runs/motion_detection/large_runs/detect/train/P_curve.png", width=600)

# %% [markdown]
# ## Recall-Confidence Curve

# %%
Image(filename="/Users/wydoinn/Documents/TeleICU Monitoring System/runs/motion_detection/large_runs/detect/train/R_curve.png", width=600)

# %% [markdown]
# ## Precision-Recall Curve

# %%
Image(filename="/Users/wydoinn/Documents/TeleICU Monitoring System/runs/motion_detection/large_runs/detect/train/PR_curve.png", width=600)

# %% [markdown]
# ## Validation Batch Results

# %%
Image(filename="/Users/wydoinn/Documents/TeleICU Monitoring System/runs/motion_detection/large_runs/detect/train/val_batch0_pred.jpg", width=600)

# %%
Image(filename="/Users/wydoinn/Documents/TeleICU Monitoring System/runs/motion_detection/large_runs/detect/train/val_batch1_pred.jpg", width=600)

# %%
Image(filename="/Users/wydoinn/Documents/TeleICU Monitoring System/runs/motion_detection/large_runs/detect/train/val_batch2_pred.jpg", width=600)
